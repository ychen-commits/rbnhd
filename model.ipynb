# %%
import os
import pandas as pd
import numpy as np

# %%
os.listdir()
# Out:
# ['equity_value_data.csv',
#  'features_data.csv',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb']

# %%
features = pd.read_csv('features_data.csv')
df = pd.read_csv('equity_value_data.csv')

# %%
df.head()
# Out:
#               timestamp  close_equity                           user_id
# 0  2016-11-16T00:00:00Z         48.16  bcef4fa9b0bdf22bcf7deae708decf03
# 1  2016-11-17T00:00:00Z         48.16  bcef4fa9b0bdf22bcf7deae708decf03
# 2  2016-11-18T00:00:00Z         48.16  bcef4fa9b0bdf22bcf7deae708decf03
# 3  2016-11-21T00:00:00Z         48.16  bcef4fa9b0bdf22bcf7deae708decf03
# 4  2016-11-22T00:00:00Z         48.16  bcef4fa9b0bdf22bcf7deae708decf03

# %% [markdown]
# #### a) percentage of churned users

# %%
import datetime

# %%
# convert timestamp column from string to datetime
df['timestamp'] = df['timestamp'].apply(lambda x: x[:10])
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# %%
# sort by user_id, timestamp, ascending
df = df.sort_values(by=['user_id', 'timestamp'])

# %%
# create another timestamp column with lag=1
df['timestamp_lag'] = df.groupby(['user_id'])['timestamp'].shift(-1)

# %%
# find the difference of days between two back-to-back timestamps with equity >= 10
df['timestamp_diff'] = df['timestamp_lag'] - df['timestamp'] - pd.Timedelta(days=1)
df['timestamp_diff'][pd.isna(df['timestamp_diff'])] = datetime.date(2017,8,18)-df['timestamp'][pd.isna(df['timestamp_diff'])]
df['timestamp_diff'] = df['timestamp_diff'].dt.days
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# find the max timestamp difference for each user
df_q1 = df.groupby(['user_id'])['timestamp_diff'].max().reset_index()

# %%
df_q1['ifchurn'] = df_q1['timestamp_diff'].apply(lambda x: 1 if x>=28 else 0)

# %%
df_q1.head()
# Out:
#                             user_id  timestamp_diff  ifchurn
# 0  0012db34aa7b083f5714e7831195e54d               3        0
# 1  001d6c77dbdb3213cead7673f250bfdc               3        0
# 2  002e4653171ddc61c3cd30603cd7bd3e               3        0
# 3  00384fa9be6fdca1b786bae70d78f88f               3        0
# 4  0042aac295a0d4df88f4b83012778bd4               3        0

# %%
df_q1['ifchurn'].value_counts()
# Out:
# 0    4579
# 1    1005
# Name: ifchurn, dtype: int64

# %%
print('percentage of churned users is {}'.format(1005/(1005+4579)))
# Out:
# percentage of churned users is 0.17997851002865328

# %% [markdown]
# #### b) build a classifier with random forest

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score, accuracy_score

# %%
df = pd.merge(features, df_q1, on='user_id')

# %%
# encode categorical features
df['risk_tolerance'] = df['risk_tolerance'].map({'low_risk_tolerance':0,
                                                 'med_risk_tolerance':1,
                                                 'high_risk_tolerance':2})

df['investment_experience'] = df['investment_experience'].map({'no_investment_exp':0,
                                                               'limited_investment_exp':1,
                                                               'good_investment_exp':2,
                                                               'extensive_investment_exp':3})

df['liquidity_needs'] = df['liquidity_needs'].map({'not_important_liq_need':0,
                                                   'somewhat_important_liq_need':1,
                                                   'very_important_liq_need':2})

df['time_horizon'] = df['time_horizon'].map({'short_time_horizon':0,
                                             'med_time_horizon':1,
                                             'long_time_horizon':2})

# %%
df = pd.concat([df, 
                pd.get_dummies(df['platform']), 
                pd.get_dummies(df['instrument_type_first_traded'])], 
               axis=1)

# %%
df.columns
# Out:
# Index(['risk_tolerance', 'investment_experience', 'liquidity_needs',
#        'platform', 'time_spent', 'instrument_type_first_traded',
#        'first_deposit_amount', 'time_horizon', 'user_id', 'timestamp_diff',
#        'ifchurn', 'Android', 'both', 'iOS', '0', 'adr', 'cef', 'etp', 'lp',
#        'mlp', 'reit', 'rlt', 'stock', 'tracking', 'wrt'],
#       dtype='object')

# %%
X = df.drop(['platform','instrument_type_first_traded','user_id','timestamp_diff', 'ifchurn'], axis=1)
y = df['ifchurn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=10, class_weight={0:1,1:5})
# clf = RandomForestClassifier(n_estimators=50, max_depth=10, class_weight='balanced')

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 5},
#             criterion='gini', max_depth=10, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
cutoff = 0.5
y_train_pred = (clf.predict_proba(X_train)[:,1]>=cutoff).astype(int)
y_test_pred = (clf.predict_proba(X_test)[:,1]>=cutoff).astype(int)

# %%
print('precision_train:{} \n'.format(precision_score(y_train, y_train_pred)), 
      'recall_train:{} \n'.format(recall_score(y_train, y_train_pred)), 
      'f1_train:{}'.format(f1_score(y_train, y_train_pred)))

print('-'*40)

print('precision_test:{} \n'.format(precision_score(y_test, y_test_pred)), 
      'recall_test:{} \n'.format(recall_score(y_test, y_test_pred)), 
      'f1_test:{}'.format(f1_score(y_test, y_test_pred)))
# Out:
# precision_train:0.4059065934065934
#  recall_train:0.7838196286472149
#  f1_train:0.534841628959276
# ----------------------------------------
# precision_test:0.3139784946236559
#  recall_test:0.5816733067729084
#  f1_test:0.4078212290502793

# %% [markdown]
# * Because the outcome label classes are imbalanced, the metrics I used here are precision, recall and f1 score.
# * I did random train test split on the data, keeping the same 0-1 label ratio in both train and test datasets
# * A random forest classifier is fitted, I restricted the number of trees and max depth of each tree, and gave more weights to samples with outcome = 1

# %% [markdown]
# #### c) feature importance

# %%
feature_importance = pd.DataFrame({'features': X_train.columns,
                                   'importance': clf.feature_importances_})

# %%
feature_importance.sort_values(['importance'], ascending=False)
# Out:
#                  features  importance
# 3              time_spent    0.313644
# 4    first_deposit_amount    0.279828
# 0          risk_tolerance    0.084087
# 1   investment_experience    0.065546
# 5            time_horizon    0.058652
# 2         liquidity_needs    0.047177
# 7                    both    0.021136
# 6                 Android    0.020359
# 8                     iOS    0.019676
# 10                    adr    0.018675
# 12                    etp    0.016825
# 17                  stock    0.016752
# 15                   reit    0.011377
# 14                    mlp    0.008033
# 13                     lp    0.005820
# 11                    cef    0.004276
# 19                    wrt    0.004186
# 16                    rlt    0.002184
# 9                       0    0.001766
# 18               tracking    0.000000

# %% [markdown]
# * the most important features are time_spent and first_deposit_amount

# %%
corr = pd.concat([y,X],axis=1).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col0 {
#             background-color:  #b40426;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col2 {
#             background-color:  #485fd1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col3 {
#             background-color:  #7597f6;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col4 {
#             background-color:  #4b64d5;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col6 {
#             background-color:  #3d50c3;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col7 {
#             background-color:  #d4dbe6;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col8 {
#             background-color:  #9abbff;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col9 {
#             background-color:  #cbd8ee;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col10 {
#             background-color:  #5875e1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col11 {
#             background-color:  #a2c1ff;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col12 {
#             background-color:  #6282ea;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col13 {
#             background-color:  #bcd2f7;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col14 {
#             background-color:  #5a78e4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col15 {
#             background-color:  #7da0f9;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col16 {
#             background-color:  #7a9df8;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col17 {
#             background-color:  #5875e1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col18 {
#             background-color:  #c9d7f0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col19 {
#             background-color:  #4257c9;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow0_col20 {
#             background-color:  #6485ec;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col1 {
#             background-color:  #b40426;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col2 {
#             background-color:  #80a3fa;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col3 {
#             background-color:  #90b2fe;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col4 {
#             background-color:  #3e51c5;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col5 {
#             background-color:  #536edd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col6 {
#             background-color:  #7b9ff9;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col7 {
#             background-color:  #cfdaea;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col8 {
#             background-color:  #98b9ff;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col9 {
#             background-color:  #cfdaea;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col10 {
#             background-color:  #5a78e4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col11 {
#             background-color:  #a9c6fd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col12 {
#             background-color:  #6788ee;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col13 {
#             background-color:  #c6d6f1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col14 {
#             background-color:  #5875e1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col15 {
#             background-color:  #80a3fa;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col16 {
#             background-color:  #81a4fb;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col17 {
#             background-color:  #5a78e4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col18 {
#             background-color:  #bcd2f7;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col19 {
#             background-color:  #3f53c6;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow1_col20 {
#             background-color:  #5875e1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col0 {
#             background-color:  #506bda;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col1 {
#             background-color:  #88abfd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col2 {
#             background-color:  #b40426;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col3 {
#             background-color:  #96b7ff;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col4 {
#             background-color:  #485fd1;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col5 {
#             background-color:  #7597f6;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col6 {
#             background-color:  #7295f4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col7 {
#             background-color:  #d3dbe7;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col8 {
#             background-color:  #a3c2fe;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col9 {
#             background-color:  #c7d7f0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col10 {
#             background-color:  #5d7ce6;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col11 {
#             background-color:  #aac7fd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col12 {
#             background-color:  #6b8df0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col13 {
#             background-color:  #d3dbe7;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col14 {
#             background-color:  #5a78e4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col15 {
#             background-color:  #80a3fa;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col16 {
#             background-color:  #80a3fa;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col17 {
#             background-color:  #5673e0;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col18 {
#             background-color:  #b1cbfc;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col19 {
#             background-color:  #445acc;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow2_col20 {
#             background-color:  #5977e3;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col0 {
#             background-color:  #4a63d3;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col1 {
#             background-color:  #6788ee;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col2 {
#             background-color:  #6384eb;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col3 {
#             background-color:  #b40426;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col4 {
#             background-color:  #3e51c5;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col5 {
#             background-color:  #536edd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col6 {
#             background-color:  #4f69d9;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col7 {
#             background-color:  #f2c9b4;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col8 {
#             background-color:  #abc8fd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col9 {
#             background-color:  #97b8ff;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col10 {
#             background-color:  #5470de;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col11 {
#             background-color:  #aac7fd;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d6b1564babrow3_col12 {
#             background-color:  #5b7ae5;
#         }    #T_676ff708_a0aa_11eb_8fb1_85d

# %%
corr['ifchurn']
# Out:
# ifchurn                  1.000000
# risk_tolerance          -0.125477
# investment_experience   -0.042086
# liquidity_needs         -0.066129
# time_spent               0.032538
# first_deposit_amount    -0.068482
# time_horizon            -0.049414
# Android                  0.032211
# both                    -0.011197
# iOS                     -0.023175
# 0                       -0.012958
# adr                     -0.021366
# cef                     -0.004679
# etp                     -0.033072
# lp                       0.019228
# mlp                      0.005198
# reit                    -0.004243
# rlt                      0.004418
# stock                    0.033013
# tracking                -0.006270
# wrt                      0.018492
# Name: ifchurn, dtype: float64
